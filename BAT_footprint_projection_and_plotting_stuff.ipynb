# %%
# !pip install ligo.skymap
# Out:
# Collecting ligo.skymap
#   Downloading ligo.skymap-0.5.3-cp36-abi3-manylinux2014_x86_64.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 48.9 MB/s
# Collecting ptemcee
#   Downloading ptemcee-1.0.0.tar.gz (17 kB)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from ligo.skymap) (1.19.5)
# Collecting reproject>=0.3.2
#   Downloading reproject-0.8-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 62.0 MB/s
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.7/dist-packages (from ligo.skymap) (4.62.3)
# Collecting ligo-segments>=1.2.0
#   Downloading ligo-segments-1.4.0.tar.gz (51 kB)
#      |████████████████████████████████| 51 kB 5.4 MB/s
# Requirement already satisfied: pillow>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from ligo.skymap) (7.1.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from ligo.skymap) (2018.9)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from ligo.skymap) (3.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from ligo.skymap) (2.6.3)
# Collecting python-ligo-lw>=1.7.0
#   Downloading python-ligo-lw-1.7.1.tar.gz (2.3 MB)
#      |████████████████████████████████| 2.3 MB 36.5 MB/s
# Collecting astropy-healpix>=0.3
#   Downloading astropy_healpix-0.6-cp37-cp37m-manylinux2010_x86_64.whl (208 kB)
#      |████████████████████████████████| 208 kB 56.1 MB/s
# Collecting lalsuite>=6.82
#   Downloading lalsuite-7.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.4 MB)
#      |████████████████████████████████| 27.4 MB 65 kB/s
# Collecting matplotlib>=3.4.0
#   Downloading matplotlib-3.5.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 58 kB/s
# Collecting astroplan>=0.7
#   Downloading astroplan-0.8.tar.gz (134 kB)
#      |████████████████████████████████| 134 kB 77.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: astropy!=4.2,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from ligo.skymap) (4.3.1)
# Collecting ligo-gracedb>=2.0.1
#   Downloading ligo-gracedb-2.7.6.tar.gz (2.3 MB)
#      |████████████████████████████████| 2.3 MB 30.2 MB/s
# Collecting healpy
#   Downloading healpy-1.15.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (18.1 MB)
#      |████████████████████████████████| 18.1 MB 185 kB/s
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from ligo.skymap) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from astroplan>=0.7->ligo.skymap) (1.15.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from astropy!=4.2,>=4.0.2->ligo.skymap) (4.8.2)
# Requirement already satisfied: pyerfa>=1.7.3 in /usr/local/lib/python3.7/dist-packages (from astropy!=4.2,>=4.0.2->ligo.skymap) (2.0.0.1)
# Collecting lscsoft-glue
#   Downloading lscsoft-glue-2.0.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 61.0 MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from lalsuite>=6.82->ligo.skymap) (2.8.2)
# Requirement already satisfied: future>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from ligo-gracedb>=2.0.1->ligo.skymap) (0.16.0)
# Collecting cryptography<=3.3.1,>=1.7.2
#   Downloading cryptography-3.3.1-cp36-abi3-manylinux2010_x86_64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 51.1 MB/s
# Requirement already satisfied: requests>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from ligo-gracedb>=2.0.1->ligo.skymap) (2.23.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography<=3.3.1,>=1.7.2->ligo-gracedb>=2.0.1->ligo.skymap) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography<=3.3.1,>=1.7.2->ligo-gracedb>=2.0.1->ligo.skymap) (2.21)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.0->ligo.skymap) (0.11.0)
# Requirement already satisfied: setuptools-scm>=4 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.0->ligo.skymap) (6.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.0->ligo.skymap) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.0->ligo.skymap) (3.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.0->ligo.skymap) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4.0->ligo.skymap) (4.28.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from python-ligo-lw>=1.7.0->ligo.skymap) (3.13)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.6.0->ligo-gracedb>=2.0.1->ligo.skymap) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.6.0->ligo-gracedb>=2.0.1->ligo.skymap) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.6.0->ligo-gracedb>=2.0.1->ligo.skymap) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.6.0->ligo-gracedb>=2.0.1->ligo.skymap) (2021.10.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from setuptools-scm>=4->matplotlib>=3.4.0->ligo.skymap) (57.4.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from setuptools-scm>=4->matplotlib>=3.4.0->ligo.skymap) (1.2.2)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->ligo.skymap) (1.5.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->astropy!=4.2,>=4.0.2->ligo.skymap) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->astropy!=4.2,>=4.0.2->ligo.skymap) (3.6.0)
# Collecting pyOpenSSL
#   Downloading pyOpenSSL-21.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.2 MB/s
# Building wheels for collected packages: astroplan, ligo-gracedb, ligo-segments, python-ligo-lw, lscsoft-glue, ptemcee
#   Building wheel for astroplan (PEP 517) ... done
#   Created wheel for astroplan: filename=astroplan-0.8-py3-none-any.whl size=83275 sha256=81118ebeb4e722fb98f76903011d1abe9fcfca429c12e2c386d6935c7a1349eb
#   Stored in directory: /root/.cache/pip/wheels/4f/c5/6d/20497dbabe23d89c54991f269460480788f7a6d15b4d1ae134
#   Building wheel for ligo-gracedb (setup.py) ... done
#   Created wheel for ligo-gracedb: filename=ligo_gracedb-2.7.6-py2.py3-none-any.whl size=2301797 sha256=dc6453145dabfdb5605f22a6f0869448a5e820c7fe0075d9bd5e0f9b3beda2dd
#   Stored in directory: /root/.cache/pip/wheels/1d/71/55/910a7243fb514a2bd4424432dcdea216722b0c3191e5b68be3
#   Building wheel for ligo-segments (setup.py) ... done
#   Created wheel for ligo-segments: filename=ligo_segments-1.4.0-cp37-cp37m-linux_x86_64.whl size=86665 sha256=aa2b617acf96df15647b1d6f1b3198ab73ab8195777531637b8fc6dd5ebc4158
#   Stored in directory: /root/.cache/pip/wheels/09/f9/d4/129b3bb4458d50b56fdc8245ace7c8216d54865fe8d3aebc05
#   Building wheel for python-ligo-lw (setup.py) ... done
#   Created wheel for python-ligo-lw: filename=python_ligo_lw-1.7.1-cp37-cp37m-linux_x86_64.whl size=181246 sha256=a70b11e24dbc9a1f00115373b7c565e31c5456ea72bf75f408282b7d61d852c4
#   Stored in directory: /root/.cache/pip/wheels/8d/b3/19/a63f74414f7afa1497ae18b384fbd9402f7d2103c0ff02fb0f
#   Building wheel for lscsoft-glue (setup.py) ... done
#   Created wheel for lscsoft-glue: filename=lscsoft_glue-2.0.0-cp37-cp37m-linux_x86_64.whl size=416847 sha256=a6e08f38ea69450ad7c5a97cf8d63778c035216e74a948019370f813152a25ea
#   Stored in directory: /root/.cache/pip/wheels/9d/ed/9e/1f9cad5e15359dc17954b893dd486760b5cb1ffd97a8405d1e
#   Building wheel for ptemcee (setup.py) ... done
#   Created wheel for ptemcee: filename=ptemcee-1.0.0-py3-none-any.whl size=18549 sha256=fa656637ce9d4f6943c2f9af23eabb57f22a02a988f604138760cbb85ada1fb6
#   Stored in directory: /root/.cache/pip/wheels/5e/5e/c5/9d08b47f943d50924b028f2a9c4b131cc3e025ee7994cea9ae
# Successfully built astroplan ligo-gracedb ligo-segments python-ligo-lw lscsoft-glue ptemcee
# Installing collected packages: cryptography, pyOpenSSL, ligo-segments, matplotlib, lscsoft-glue, astropy-healpix, reproject, python-ligo-lw, ptemcee, ligo-gracedb, lalsuite, healpy, astroplan, ligo.skymap
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed astroplan-0.8 astropy-healpix-0.6 cryptography-3.3.1 healpy-1.15.0 lalsuite-7.1 ligo-gracedb-2.7.6 ligo-segments-1.4.0 ligo.skymap-0.5.3 lscsoft-glue-2.0.0 matplotlib-3.5.0 ptemcee-1.0.0 pyOpenSSL-21.0.0 python-ligo-lw-1.7.1 reproject-0.8

# %%
import numpy as np
import time
import datetime
from astropy.time import Time
from urllib.request import urlopen
from bs4 import BeautifulSoup
import math
import ephem
def unix2met(unixtime):
    """Convert Unix time to Spacecraft time"""
    return int(unixtime) - time.mktime((2001,1,1,0,0,0,0,0,0))+(unixtime-int(unixtime))

# %% [markdown]
# Attitude

# %%
from astropy.time import Time
import requests
import urllib.parse
import os, sys, json

def unix2mjd(unixtime):
    """Convert UNIX timestamp into MJD"""
    dt = Time(unixtime,format='unix',scale='utc')
    return dt.mjd

def get_attitude(trigtime_obj):
  unixtime=time.mktime(trigtime_obj.timetuple())
  mjd=unix2mjd(unixtime)
  base = 'https://www.swift.psu.edu/operations/afst_json.php?mjdstart='
  url = base+str(mjd)
  #print(url)
  r = requests.get(url = url)
  #print(json.loads(r.text))
  if len(json.loads(r.text)['api_data']['entries']) < 1:
    print('No pointing info available for this time. Maybe wait?')
    return -1,-1,-1
  else:
    settle_time = datetime.datetime.strptime(json.loads(r.text)['api_data']['entries'][0]['api_data']['settle'], "%Y-%m-%d %H:%M:%S")
    if trigtime_obj<settle_time:
      print('WARNING: Trigger time in slew. ObsSchedule pointing info not reliable. Must use attitude file.')
      return -1,-1,-1
    else:
      ra=float(json.loads(r.text)['api_data']['entries'][0]['api_data']['ra'])
      dec=float(json.loads(r.text)['api_data']['entries'][0]['api_data']['dec'])
      roll=float(json.loads(r.text)['api_data']['entries'][0]['api_data']['roll'])
      return ra,dec,roll

# %% [markdown]
# Attitude File Method

# %%
url = 'https://www.swift.ac.uk/archive/reproc/00013984050/auxil/sw00013984050sat.fits.gz'
from astropy.utils.data import download_file
from astropy.io import fits

attfile = download_file(url)

att = fits.open(attfile)
att_data=att[1].data
utcf=att[1].header['utcfinit']
print(T0-utcf)
for pointing in att_data:
  #print(pointing)
  if abs(pointing[0]-T0+utcf) < 3:
  #if pointing[0]>637413000:
    print(pointing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5a810b6be821> in <module>()
#       9 att_data=att[1].data
#      10 utcf=att[1].header['utcfinit']
# ---> 11 print(T0-utcf)
#      12 for pointing in att_data:
#      13   #print(pointing)
#
# NameError: name 'T0' is not defined

# %%
utcf

# %% [markdown]
# # Query the BAT polygon I made for Treasure Map

# %%
api_token = 'zeH0plj1hlUo0OWskopBddaQB8M8VwwYc1m86Q'
BASE = 'http://treasuremap.space/api/v0'

import requests
import urllib.parse
import os, sys, json
import numpy as np

#Using this function to convert the string Polygons to a list of points
def sanatize_footprint_ccds(ccds):
    footprint_ccds = []
    for footprint in ccds:
        sanitized = footprint.strip('POLYGON ').strip(')(').split(',')
        polygon = []
        for vertex in sanitized:
            obj = vertex.split()
            ra = float(obj[0])
            dec = float(obj[1])
            polygon.append([ra,dec])
        footprint_ccds.append(polygon)
    return footprint_ccds

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection

TARGET = 'footprints'

params = {
            "api_token":api_token,
            "name":"Swift Burst Alert Telescope"
        }

url = "{}/{}?{}".format(BASE, TARGET, urllib.parse.urlencode(params))
r = requests.get(url = url)

print("Requested Footprint Info")

footprints = json.loads(r.text)
polygons = []
patches = []

#This gets all of the Polygon information from the json list
for f in footprints:
    f_info = json.loads(f)
    polygons.append(f_info['footprint'])

#converts the polygons to a list of list of points (list of polygons)
sanatized_ccds = sanatize_footprint_ccds(polygons)

#gather the points for ylim and xlim
xs, ys = [], []

for sc in sanatized_ccds:
    #add the polygon list of points to the matplotlib patch collection
    patches.append(Polygon(sc, False))
    for p in sc:
        xs.append(p[0])
        ys.append(p[1])
    
p = PatchCollection(patches, alpha=0.4)

fig, ax = plt.subplots()
ax.set_xlim(min(xs)-.1, max(xs)+.1)
ax.set_ylim(min(ys)-.1, max(ys)+.1)
ax.add_collection(p)
plt.show()
# Out:
# Requested Footprint Info

# %%
def ra_dec_to_uvec(ra, dec):
    phi = np.deg2rad(90 - dec)
    theta = np.deg2rad(ra)
    x = np.cos(theta) * np.sin(phi)
    y = np.sin(theta) * np.sin(phi)
    z = np.cos(phi)
    return x, y, z

def uvec_to_ra_dec(x, y, z):
    r = np.sqrt(x**2 + y ** 2 + z ** 2)
    x /= r
    y /= r
    z /= r
    theta = np.arctan2(y, x)
    phi = np.arccos(z)
    dec = 90 - np.rad2deg(phi)
    if theta < 0:
        ra = 360 + np.rad2deg(theta)
    else:
        ra = np.rad2deg(theta)
    return ra, dec

def x_rot(theta_deg):
    theta = np.deg2rad(theta_deg)
    return np.matrix([
        [1, 0, 0],
        [0, np.cos(theta), -np.sin(theta)],
        [0, np.sin(theta), np.cos(theta)]
    ])

def y_rot(theta_deg):
    theta = np.deg2rad(theta_deg)
    return np.matrix([
        [np.cos(theta), 0, np.sin(theta)],
        [0, 1, 0],
        [-np.sin(theta), 0, np.cos(theta)]
    ])

def z_rot(theta_deg):
    theta = np.deg2rad(theta_deg)
    return np.matrix([
        [np.cos(theta), -np.sin(theta), 0],
        [np.sin(theta), np.cos(theta), 0],
        [0, 0, 1]
    ])


def project_footprint(footprint, ra, dec, pos_angle):
    if pos_angle is None:
        pos_angle = 0.0

    footprint_zero_center_ra = np.asarray([pt[0] for pt in footprint])
    footprint_zero_center_dec = np.asarray([pt[1] for pt in footprint])
    footprint_zero_center_uvec = ra_dec_to_uvec(footprint_zero_center_ra, footprint_zero_center_dec)
    footprint_zero_center_x, footprint_zero_center_y, footprint_zero_center_z = footprint_zero_center_uvec
    proj_footprint = []
    for idx in range(footprint_zero_center_x.shape[0]):
        vec = np.asarray([footprint_zero_center_x[idx], footprint_zero_center_y[idx], footprint_zero_center_z[idx]])
        new_vec = vec @ x_rot(-pos_angle) @ y_rot(dec) @ z_rot(-ra)
        new_x, new_y, new_z = new_vec.flat
        pt_ra, pt_dec = uvec_to_ra_dec(new_x, new_y, new_z)
        proj_footprint.append([pt_ra, pt_dec])
    return proj_footprint

# %% [markdown]
# # Plot that BAT footprint on top of a GW or Fermi skymap

# %%
from ligo.skymap.io import *
import ligo.skymap
from ligo.skymap.tool.ligo_skymap_plot import main
import ligo.skymap.io
import ligo.skymap.postprocess

# %%
import numpy as np
from astropy.utils.data import download_file

from astropy.coordinates import SkyCoord
from astropy.io import fits
from astropy import units as u

from matplotlib import rcParams
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import healpy as hp

# %% [markdown]
# Stuff needed for Earth occultation plotting

# %%
def getDataFromTLE(datetime, tleLatOffset=0, tleLonOffset=0.21):
    # Get TLE and parse
    url = "https://celestrak.com/satcat/tle.php?CATNR=28485"
    data = urlopen(url)
    tle_raw=data.read()
    clean_tle = ''.join(BeautifulSoup(tle_raw, "html.parser").stripped_strings)
    tle_obj = clean_tle.split('\r\n')

    # Print age of TLE
    year = "20"+tle_obj[1][18:20]
    day = tle_obj[1][20:32]
    #print("\nTLE most recently updated "+year+"DOY"+ day)
    
    # Create spacecraft instance
    Swift = ephem.readtle(tle_obj[0],tle_obj[1],tle_obj[2])
    
    # Create observer
    observer_Swift = ephem.Observer()
    observer_Swift.lat = '0'
    observer_Swift.long = '0'
    
    # Initialize lists
    lat = []
    lon = []
    elevation = []
    
    # Iterate through time; compute predicted locations
    observer_Swift.date = ephem.date(datetime)
    
    try:
        Swift.compute(observer_Swift)
    except:
        print('Cant compute observer, maybe TLE too old?')
        return False, False, False

    lat.append(np.degrees(Swift.sublat.znorm))
    lon.append(np.degrees(Swift.sublong.norm))
    elevation.append(Swift.elevation)
    # Correct for inaccuracy
    lon = np.array(lon) - tleLonOffset
    lat = np.array(lat) - tleLatOffset
    
    if len(lon) == 1: # Return single value instead of array if length is 1
        lon = lon[0]
        lat = lat[0]
        elevation = elevation[0]

    return lon, lat, elevation

# %%
def deg2dm(deg):
    sign = np.sign(deg)
    deg = np.abs(deg)
    d = np.floor(deg)
    m = (deg - d) * 60
    return int(sign*d), m

# %%
def getGeoCenter(datetime, lon, lat):
    # Define the observer to be at the location of the spacecraft
    observer = ephem.Observer()

    # Convert the longitude to +E (-180 to 180)
    if lon > 180:
       lon = (lon % 180) - 180

    lon_deg, lon_min = deg2dm(lon)
    lat_deg, lat_min = deg2dm(lat)

    lon_string = '%s:%s' % (lon_deg, lon_min)
    lat_string = '%s:%s' % (lat_deg, lat_min)

    observer.lon = lon_string
    observer.lat = lat_string
    
    # Set the time of the observations
    observer.date = ephem.date(datetime)
    
    # Get the ra and dec (in radians) of the point in the sky at altitude = 90 (directly overhead)
    ra_zenith_radians, dec_zenith_radians = observer.radec_of('0', '90')
    
    # convert the ra and dec to degrees
    ra_zenith = np.degrees(ra_zenith_radians)
    dec_zenith = np.degrees(dec_zenith_radians)
    
    ra_geocenter =  (ra_zenith+180) % 360
    dec_geocenter = -1 * dec_zenith
    
    return ra_geocenter, dec_geocenter

# %%
def getearthsatpos(datetime):
    tleLonOffset=0.21
    tleLatOffset = 0

    try:
        lon, lat, elevation= getDataFromTLE(datetime, tleLatOffset=tleLatOffset, tleLonOffset=tleLonOffset)
    except:
        return False, False, False

    if lon == False and lat == False and elevation == False:
        return False, False, False

    # Get the geo center coordinates in ra and dec
    ra_geocenter, dec_geocenter = getGeoCenter(datetime, lon, lat)

    EARTH_RADIUS = 6378.140 * 1000 #in meters
    dtor = math.pi/180
    elev = elevation + EARTH_RADIUS
    earthsize_rad = np.arcsin(EARTH_RADIUS/elev)/dtor

    return ra_geocenter,dec_geocenter, earthsize_rad

# %%
def makeEarthContour(ra,dec,radius):
    thetas = np.linspace(0, -2*np.pi, 200)
    ras = radius * np.cos(thetas)
    decs = radius * np.sin(thetas)
    contour = np.c_[ras,decs]
    Earthcont = project_footprint(contour, ra, dec, 0)
    return Earthcont

# %% [markdown]
# Code for splitting polygons if they span 0 deg RA

# %%
from operator import itemgetter
def splitter(batfootprint):
  hi=[]
  lo=[]
  for coord in batfootprint:
    if coord[0]>180:
      hi.append([coord[0],coord[1]])
    else:
      lo.append([coord[0],coord[1]])
  hi=sorted(hi,key=itemgetter(1))


  step = abs(lo[-1][1]-lo[0][1])/20
  if lo[-1][1] > 0:
    init = lo[-1][1]
  else:
    init = lo[0][1]
  for i in range(20):
    lo.append([0.1,init-i*step])

  step = abs(hi[-1][1]-hi[0][1])/20
  while step < 0.1:
    hi= hi[:-1]
    step = abs(hi[-1][1]-hi[0][1])/20
  if hi[-1][1] > 0:
    init = hi[-1][1]
  else:
    init = hi[0][1]
  for i in range(20):
    hi.append([359.9,init-i*step])

  return lo,hi

# %% [markdown]
# Make the damn figure already

# %%
s='2021-11-18T23:38:56'
trigtime_obj=datetime.datetime.strptime(s, "%Y-%m-%dT%H:%M:%S")
print(trigtime_obj)
unixtime = time.mktime(trigtime_obj.timetuple())
print(unixtime)
T0=unix2met(unixtime)
print(T0+25.385)
# Out:
# 2021-11-18 23:38:56
# 1637278736.0
# 658971561.385

# %%
ra,dec,roll = get_attitude(trigtime_obj)
ra,dec,roll=  263.011 ,	 53.674 	, 215.000 	
print(ra,dec,roll)
# Out:
# No pointing info available for this time. Maybe wait?
# 263.011 53.674 215.0

# %%
batfootprint=project_footprint(sc, ra,dec,360-roll)

# %%
url = 'https://heasarc.gsfc.nasa.gov/FTP/fermi/data/gbm/triggers/2020/bn200817393/quicklook/glg_healpix_all_bn200817393.fit'
#url = 'http://gcn.gsfc.nasa.gov/notices_f/gbm_gnd_loc_map_658971499.fits'
skymapfile = download_file(url, cache=True) 
#skymap, metadata = ligo.skymap.io.fits.read_sky_map(url, nest=True, distances=False)

nside=hp.get_nside(skymap)
skymap = hp.read_map(skymapfile)
nside = 128
deg2perpix = hp.nside2pixarea(nside, degrees=True)
probperdeg2 = skymap / deg2perpix
annotate = True
contour = (50,90)

# %%
12*128**2
# Out:
# 196608

# %%
fig = plt.figure(figsize=(15, 15), dpi=100)

center = SkyCoord(116, -72, unit="deg")  # defaults to ICRS frame
ax = plt.axes(projection='astro hours mollweide')#, center = center, radius = 50*u.degree)#radius, center options
ax.grid()
try:
  vmax = probperdeg2.max()
  print('yes')
  img = ax.imshow_hpx((probperdeg2, 'ICRS'), nested=False, vmin=0., vmax=vmax, cmap='cylon')
  print('yes')
  cls = 100* ligo.skymap.postprocess.util.find_greedy_credible_levels(skymap)
  #cs = ax.contour_hpx((cls, 'ICRS'), nested=metadata['nest'],colors='k', linewidths=0.5, levels=(50,90))
except:
  print('No map')
fmt = r'%g\%%' if rcParams['text.usetex'] else '%g%%'
#plt.clabel(cs, fmt=fmt, fontsize=6, inline=True)


ra,dec,radius = getearthsatpos(trigtime_obj)
earthfoot=makeEarthContour(ra,dec,radius)
from matplotlib.patches import Polygon
earth = Polygon( earthfoot, facecolor='blue', edgecolor='green', alpha=0.4, closed=True, transform=ax.get_transform('fk5'))
ax.add_patch(earth)

ax.plot_coord(SkyCoord(21,70, unit='deg'),'o',markerfacecolor ='blue',markersize=10)
#ax.text(30, 65,'182,52', transform=ax.get_transform('fk5'),fontsize=15, color='blue')

poly = Polygon( batfootprint, facecolor='green', edgecolor='green', alpha=0.4, closed=True, transform=ax.get_transform('fk5'))
ax.add_patch(poly)

split=True
if split:
  lo,hi=splitter(earthfoot)
  polylo = Polygon( lo, facecolor='green', edgecolor='blue', alpha=0.4, closed=True, transform=ax.get_transform('fk5'))
  ax.add_patch(polylo)
  polyhi = Polygon( hi, facecolor='green', edgecolor='blue', alpha=0.4, closed=True, transform=ax.get_transform('fk5'))
  ax.add_patch(polyhi)


ligo.skymap.plot.outline_text(ax)
plt.title('Fermi 211024A')
# Out:
# yes
# yes
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-c825103340f2> in <module>()
#      35 split=True
#      36 if split:
# ---> 37   lo,hi=splitter(earthfoot)
#      38   polylo = Polygon( lo, facecolor='green', edgecolor='blue', alpha=0.4, closed=True, transform=ax.get_transform('fk5'))
#      39   ax.add_patch(polylo)
#
# <ipython-input-15-799c2fb7d159> in splitter(batfootprint)
#      19     lo.append([0.1,init-i*step])
#      20
# ---> 21   step = abs(hi[-1][1]-hi[0][1])/20
#      22   while step < 0.1:
#      23     hi= hi[:-1]
#
# IndexError: list index out of range
